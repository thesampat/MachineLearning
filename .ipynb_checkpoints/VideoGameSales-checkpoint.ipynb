# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ps4 = pd.read_csv('/home/sam/Desktop/MachienLearning/MachineLearning22/datasets/new/game/PS4_GamesSales.csv', encoding='latin1')
other = pd.read_csv('/home/sam/Desktop/MachienLearning/MachineLearning22/datasets/new/game/Video_Games_Sales_as_at_22_Dec_2016.csv', encoding='latin1')
xbox = pd.read_csv('/home/sam/Desktop/MachienLearning/MachineLearning22/datasets/new/game/XboxOne_GameSales.csv', encoding='latin1')

# %%
files = [ps4, other, xbox]

# %%
for file in files:
    file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Game           1034 non-null   object
#  1   Year           825 non-null    float64
#  2   Genre          1034 non-null   object
#  3   Publisher      825 non-null    object
#  4   North America  1034 non-null   float64
#  5   Europe         1034 non-null   float64
#  6   Japan          1034 non-null   float64
#  7   Rest of World  1034 non-null   float64
#  8   Global         1034 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 72.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
# ...

# %%
df = other

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %%
drop_cols = ['Critic_Score', 'Critic_Count', 'User_Score', 'User_Count', 'Rating']

# %%
df.drop(drop_cols, axis =1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Developer        10096 non-null  object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# handling object variables
obj = [col for col in df.columns if df[col].dtype == 'O']

# %%
for col in obj:
    print(f'{col}  : {len(df[col].unique())}')
# Out:
# Name  : 11563
# Platform  : 31
# Genre  : 13
# Publisher  : 583
# Developer  : 1697

# %%
plt.figure(figsize =(12,6))
sns.countplot(df['Genre'])
# Out:
# /home/sam/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
plt.figure(figsize =(16,6))
sns.countplot(df['Platform'], orient='h')
# Out:
# /home/sam/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Platform', ylabel='count'>

# %%
num = [col for col in df.columns if df[col].dtype != 'O'if 'Year_of_Release' not in col]

# %%
for col in num:
    print(f'{col} : {len(df[col].unique())}')
# Out:
# NA_Sales : 402
# EU_Sales : 307
# JP_Sales : 244
# Other_Sales : 155
# Global_Sales : 629

# %%
plt.plot(df['Global_Sales'], df['EU_Sales'])

# %%
df.groupby(['Global_Sales']).size().sort_values(ascending= False).head().plot()
# Out:
# <AxesSubplot:xlabel='Global_Sales'>

# %%
df.groupby(['EU_Sales']).size().sort_values(ascending= False).head().plot()
# Out:
# <AxesSubplot:xlabel='EU_Sales'>

# %%
df.groupby(['Global_Sales']).size().sort_values(ascending= False).head().plot()
# Out:
# <AxesSubplot:xlabel='Global_Sales'>

# %%
df.columns = df.columns.str.replace('Year_of_Release', 'year')

# %%
df.groupby(['year'])['NA_Sales'].median().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.groupby(['year'])['EU_Sales'].median().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.groupby(['year'])['JP_Sales'].median().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
plt.figure(figsize = (19, 6))
df.groupby(['Developer'])['Global_Sales'].sum().sort_values(ascending = False).head(70).plot.bar()
# Out:
# <AxesSubplot:xlabel='Developer'>

# %%
plt.figure(figsize = (19, 6))
df.groupby(['Developer'])['EU_Sales'].sum().sort_values(ascending = False).head(30).plot.bar()
# Out:
# <AxesSubplot:xlabel='Developer'>

# %%
plt.figure(figsize = (19, 6))
df.groupby(['Developer'])['JP_Sales'].sum().sort_values(ascending = False).head(30).plot.bar()
# Out:
# <AxesSubplot:xlabel='Developer'>

# %%
plt.figure(figsize = (19, 6))
df.groupby(['Developer'])['NA_Sales'].sum().sort_values(ascending = False).head(30).plot.bar()
# Out:
# <AxesSubplot:xlabel='Developer'>

# %%
plt.figure(figsize = (19, 6))
plt.title('NA')
df.groupby(['Platform'])['NA_Sales'].sum().sort_values(ascending = False).head(30).plot.bar()
plt.title('JP')
plt.figure(figsize = (19, 6))
df.groupby(['Platform'])['JP_Sales'].sum().sort_values(ascending = False).head(30).plot.bar()
plt.title('EU')
plt.figure(figsize = (19, 6))
df.groupby(['Platform'])['EU_Sales'].sum().sort_values(ascending = False).head(30).plot.bar()
# Out:
# <AxesSubplot:xlabel='Platform'>

# %%
# lets check most used catogarical feature
for col in obj:
    print(f'{col} : {df[col].mode()}')
# Out:
# Name : 0    Need for Speed: Most Wanted
# dtype: object
# Platform : 0    PS2
# dtype: object
# Genre : 0    Action
# dtype: object
# Publisher : 0    Electronic Arts
# dtype: object
# Developer : 0    Ubisoft
# dtype: object

# %%
# most used features
for col in obj:
    plt.figure()
    plt.title(col)
    df.groupby([col]).size().sort_values(ascending = False).head(5).plot.bar()

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Name               2
# Platform           0
# year             269
# Genre              2
# Publisher         54
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Developer       6623
# dtype: int64

# %%
df['year'] = df['year'].fillna(df['year'].mode(), axis =0, inplace = True)
